# %% [markdown]
# <a href="https://colab.research.google.com/github/mireillejb/FallDetectionSys/blob/main/without_test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# only train and val data

# %%
# 1. Install required packages
# !pip install kagglehub opencv-python tqdm tensorflow-hub

# 2. Import all necessary libraries
import os
from os.path import isfile, join
import time
import zipfile
import random
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import cv2
import tensorflow as tf
import tensorflow_hub as hub
print("TensorFlow version:", tf.__version__)

from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Dense, Conv1D, MaxPooling1D, LSTM, TimeDistributed, Flatten, Input,
    Dropout, BatchNormalization, Add, GlobalAveragePooling1D, Lambda, Layer
)
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from tqdm import tqdm
# Out:
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (0.3.12)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: tensorflow-hub in /usr/local/lib/python3.12/dist-packages (0.16.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub) (2.32.4)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow-hub) (5.29.5)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow-hub) (2.19.0)
# Requirement already satisfied: tensorflow<2.20,>=2.19 in /usr/local/lib/python3.12/dist-packages (from tf-keras>=2.14.1->tensorflow-hub) (2.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub) (2025.8.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.74.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.17.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.1.2)
# TensorFlow version: 2.19.0

# %%
import kagglehub
path = kagglehub.dataset_download("tuyenldvn/falldataset-imvia")
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/falldataset-imvia

# %%
# 4. Explore dataset
import os
for root, dirs, files in os.walk(path):
    print(f"{root} -> {len(files)} files")

# Find all .avi videos
from google.colab.patches import cv2_imshow
video_files = [os.path.join(dp, f) for dp, dn, fn in os.walk(path) for f in fn if f.endswith(".avi")]
print(f"Found {len(video_files)} videos.")

cap = cv2.VideoCapture(video_files[0])
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
for i in tqdm(range(frame_count)):
    ret, frame = cap.read()
    if not ret:
        break
    if i == 0:  # Show first frame
        cv2_imshow(frame)
cap.release()
# Out:
# /kaggle/input/falldataset-imvia -> 1 files
# /kaggle/input/falldataset-imvia/Lecture_room -> 0 files
# /kaggle/input/falldataset-imvia/Lecture_room/Lecture room -> 27 files
# /kaggle/input/falldataset-imvia/Coffee_room_02 -> 0 files
# /kaggle/input/falldataset-imvia/Coffee_room_02/Coffee_room_02 -> 0 files
# /kaggle/input/falldataset-imvia/Coffee_room_02/Coffee_room_02/Videos -> 22 files
# /kaggle/input/falldataset-imvia/Coffee_room_02/Coffee_room_02/Annotations_files -> 22 files
# /kaggle/input/falldataset-imvia/Home_01 -> 0 files
# /kaggle/input/falldataset-imvia/Home_01/Home_01 -> 0 files
# /kaggle/input/falldataset-imvia/Home_01/Home_01/Videos -> 30 files
# /kaggle/input/falldataset-imvia/Home_01/Home_01/Annotation_files -> 30 files
# /kaggle/input/falldataset-imvia/Office -> 0 files
# /kaggle/input/falldataset-imvia/Office/Office -> 33 files
# /kaggle/input/falldataset-imvia/Coffee_room_01 -> 0 files
# /kaggle/input/falldataset-imvia/Coffee_room_01/Coffee_room_01 -> 0 files
# /kaggle/input/falldataset-imvia/Coffee_room_01/Coffee_room_01/Videos -> 48 files
# /kaggle/input/falldataset-imvia/Coffee_room_01/Coffee_room_01/Annotation_files -> 48 files
# /kaggle/input/falldataset-imvia/Home_02 -> 0 files
# /kaggle/input/falldataset-imvia/Home_02/Home_02 -> 0 files
# /kaggle/input/falldataset-imvia/Home_02/Home_02/Videos -> 30 files
# /kaggle/input/falldataset-imvia/Home_02/Home_02/Annotation_files -> 30 files
# Found 190 videos.
#   0%|          | 0/285 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=320x240>
# 100%|██████████| 285/285 [00:00<00:00, 2193.32it/s]

# %%
# 5. Download and setup MoveNet
# !wget https://tfhub.dev/google/lite-model/movenet/singlepose/thunder/3?lite-format=tflite -O movenet_thunder.tflite

# Load MoveNet Thunder model from TensorFlow Hub
movenet = hub.load("https://tfhub.dev/google/movenet/singlepose/thunder/4")

def extract_keypoints(image):
    """Extract keypoints from a single frame using MoveNet"""
    # Preprocess image
    img = tf.image.resize_with_pad(np.expand_dims(image, axis=0), 256, 256)
    img = tf.cast(img, dtype=tf.int32)

    # Run model
    outputs = movenet.signatures['serving_default'](img)
    keypoints = outputs['output_0'].numpy()  # shape (1,1,17,3)

    return keypoints[0, 0, :, :]  # return (x,y,confidence), shape (17,3)

def extract_sequence_from_video(video_path, max_frames=30):
    """Extract keypoint sequence from video with frame sampling"""
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Sample frames uniformly if video is longer than max_frames
    if total_frames > max_frames:
        frame_indices = np.linspace(0, total_frames-1, max_frames, dtype=int)
    else:
        frame_indices = list(range(total_frames))

    frames_keypoints = []
    for frame_idx in frame_indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)
        ret, frame = cap.read()
        if not ret:
            break

        kp = extract_keypoints(frame)
        frames_keypoints.append(kp)

    cap.release()

    # Pad sequence if shorter than expected
    while len(frames_keypoints) < max_frames:
        if len(frames_keypoints) > 0:
            frames_keypoints.append(frames_keypoints[-1])  # Repeat last frame
        else:
            frames_keypoints.append(np.zeros((17, 3)))  # Zero padding

    return np.array(frames_keypoints)
# Out:
# --2025-08-24 12:10:16--  https://tfhub.dev/google/lite-model/movenet/singlepose/thunder/3?lite-format=tflite
# Resolving tfhub.dev (tfhub.dev)... 35.244.233.98
# Connecting to tfhub.dev (tfhub.dev)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.kaggle.com/models/google/movenet/tfLite/singlepose-thunder/1?lite-format=tflite&tfhub-redirect=true [following]
# --2025-08-24 12:10:17--  https://www.kaggle.com/models/google/movenet/tfLite/singlepose-thunder/1?lite-format=tflite&tfhub-redirect=true
# Resolving www.kaggle.com (www.kaggle.com)... 35.244.233.98
# Connecting to www.kaggle.com (www.kaggle.com)|35.244.233.98|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://storage.googleapis.com/kagglesdsdata/models/1026/1187/3.tflite?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20250823%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20250823T062735Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=... [following]
# --2025-08-24 12:10:17--  https://storage.googleapis.com/kagglesdsdata/models/1026/1187/3.tflite?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20250823%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20250823T062735Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.202.207, 173.194.203.207, 74.125.199.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.202.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25025596 (24M) [application/octet-stream]
# Saving to: ‘movenet_thunder.tflite’
#
# movenet_thunder.tfl 100%[===================>]  23.87M  25.3MB/s    in 0.9s
#
# 2025-08-24 12:10:18 (25.3 MB/s) - ‘movenet_thunder.tflite’ saved [25025596/25025596]

# %%
# 6. Fixed Dataset Processing Functions
def read_annotation_file(annotation_path):
    """
    Read annotation file and extract fall information
    Returns: (fall_start_frame, fall_end_frame, frame_annotations, has_explicit_fall_period)
    """
    try:
        with open(annotation_path, 'r') as f:
            lines = f.readlines()

        # First two lines contain fall start and end frames
        fall_start = int(lines[0].strip())
        fall_end = int(lines[1].strip())

        # Determine if an explicit fall period is marked
        has_explicit_fall_period = (fall_start > 0 or fall_end > 0)

        # Remaining lines contain frame annotations
        frame_annotations = []
        for line in lines[2:]:
            if line.strip():  # Skip empty lines
                parts = line.strip().split(',')
                if len(parts) >= 6:  # frame, label, x1, y1, x2, y2
                    frame_num = int(parts[0])
                    label = int(parts[1])  # This is the fall label (0=no fall, 1=fall, etc.)
                    frame_annotations.append((frame_num, label))

        return fall_start, fall_end, frame_annotations, has_explicit_fall_period
    except Exception as e:
        print(f"Error reading annotation file {annotation_path}: {e}")
        return 0, 0, [], False # Return False for has_explicit_fall_period in case of error

def find_annotation_file(video_path, dataset_path):
    """Find corresponding annotation file for a video"""
    video_name = os.path.splitext(os.path.basename(video_path))[0]

    # Common annotation file patterns
    possible_names = [
        f"{video_name}.txt",
        f"{video_name}_annotation.txt",
        f"{video_name}.annotation",
        f"annotation_{video_name}.txt"
    ]

    # Search in the dataset directory and subdirectories
    for root, dirs, files in os.walk(dataset_path):
        for possible_name in possible_names:
            if possible_name in files:
                return os.path.join(root, possible_name)

    return None

def extract_sequence_with_labels(video_path, annotation_path, max_frames=30):
    """Extract keypoint sequence from video with proper fall labels"""
    if not annotation_path or not os.path.exists(annotation_path):
        print(f"No annotation file found for {video_path}")
        return None, None

    # Read annotation file - get the new flag
    fall_start, fall_end, frame_annotations, has_explicit_fall_period = read_annotation_file(annotation_path)

    # Apply the new rule: if fall_start and fall_end are both 0, it's a No Fall video
    if not has_explicit_fall_period and fall_start == 0 and fall_end == 0:
        # Process frames but assign a No Fall label regardless
        print(f"Explicitly labeled as No Fall by 0,0 start/end frames: {video_path}")
        sequence = extract_sequence_from_video(video_path, max_frames) # Still need to extract sequence
        if sequence.shape[0] > 0:
             return sequence, 0 # Assign label 0 (No Fall)
        else:
             return None, None

    if not frame_annotations:
        print(f"No frame annotations found in {annotation_path}")
        # If there's no explicit fall period and no frame annotations, assume no fall
        if not has_explicit_fall_period:
             sequence = extract_sequence_from_video(video_path, max_frames)
             if sequence.shape[0] > 0:
                 return sequence, 0 # Assign label 0 (No Fall)
             else:
                 return None, None
        else:
            # If there was an explicit fall period but no frame annotations, something is wrong
            print(f"Warning: Explicit fall period ({fall_start}-{fall_end}) but no frame annotations in {annotation_path}")
            sequence = extract_sequence_from_video(video_path, max_frames)
            if sequence.shape[0] > 0:
                 return sequence, 1 # Assume fall based on explicit period
            else:
                 return None, None


    # Extract keypoints from video
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    if total_frames == 0:
        print(f"Could not read frames from {video_path}")
        cap.release()
        return None, None

    # Create frame-to-label mapping based on frame annotations
    frame_labels = {}
    for frame_num, label in frame_annotations:
        # Convert label: 0=no fall, 1,2,3,4=different fall states -> 0=no fall, 1=fall
        fall_label = 1 if label > 0 else 0
        frame_labels[frame_num] = fall_label

    # Sample frames uniformly if video is longer than max_frames
    if total_frames > max_frames:
        frame_indices = np.linspace(0, total_frames-1, max_frames, dtype=int)
    else:
        frame_indices = list(range(total_frames))

    frames_keypoints = []
    frame_labels_sequence = []

    for frame_idx in frame_indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)
        ret, frame = cap.read()
        if not ret:
            break

        # Extract keypoints
        kp = extract_keypoints(frame)
        frames_keypoints.append(kp)

        # Get label for this frame (frame indices are 1-based in annotations)
        frame_label = frame_labels.get(frame_idx + 1, 0)  # Default to 0 if not found
        frame_labels_sequence.append(frame_label)

    cap.release()

    # Pad sequences if shorter than expected
    while len(frames_keypoints) < max_frames:
        if len(frames_keypoints) > 0:
            frames_keypoints.append(frames_keypoints[-1])  # Repeat last frame
            frame_labels_sequence.append(frame_labels_sequence[-1])  # Repeat last label
        else:
            frames_keypoints.append(np.zeros((17, 3)))  # Zero padding
            frame_labels_sequence.append(0)  # Default to no fall

    # Determine overall sequence label based on frame annotations IF no explicit 0,0 start/end
    # If any frame in the sequence is labeled as fall, consider it a fall sequence
    sequence_label = 1 if any(label == 1 for label in frame_labels_sequence) else 0


    return np.array(frames_keypoints), sequence_label

def process_dataset_with_better_heuristics(video_files, max_frames=30, val_size=0.2):
    """Process dataset with improved heuristic labeling when annotations aren't available"""
    X, y, video_names = [], [], []

    print("Processing videos with improved heuristic detection...")
    for video_path in tqdm(video_files):
        try:
            sequence = extract_sequence_from_video(video_path, max_frames)
            if sequence.shape[0] > 0:
                X.append(sequence)

                # Get full path for better analysis
                full_path = video_path.lower()
                filename = os.path.basename(video_path).lower()

                # Enhanced fall detection patterns
                fall_indicators = [
                    'fall', 'falling', 'fell', 'tumble', 'stumble', 'trip', 'slip',
                    'drop', 'collapse', 'accident', 'emergency'
                ]
                no_fall_indicators = [
                    'walk', 'walking', 'stand', 'standing', 'sit', 'sitting',
                    'normal', 'regular', 'adl', 'daily', 'routine', 'activity',
                    'bend', 'bending', 'crouch', 'crouching', 'exercise'
                ]

                # Check for patterns in filename and path
                has_fall = any(pattern in full_path for pattern in fall_indicators)
                has_no_fall = any(pattern in full_path for pattern in no_fall_indicators)

                # Additional heuristics based on common dataset structures
                if 'fall' in os.path.dirname(video_path).lower():
                    has_fall = True
                elif any(word in os.path.dirname(video_path).lower() for word in ['normal', 'adl', 'activity']):
                    has_no_fall = True

                # Video index based heuristics (some datasets use numbering)
                # This is dataset specific - you might need to adjust
                try:
                    # Extract number from filename
                    import re
                    numbers = re.findall(r'\d+', filename)
                    if numbers:
                        video_num = int(numbers[0])
                        # Common pattern: first half are falls, second half are normal
                        # Adjust this based on your dataset structure
                        if video_num <= len(video_files) // 2:
                            has_fall = True
                        else:
                            has_no_fall = True
                except:
                    pass

                # Assign label
                if has_fall and not has_no_fall:
                    label = 1
                elif has_no_fall and not has_fall:
                    label = 0
                else:
                    # If unclear, try to balance the dataset
                    # You might need to manually check these videos
                    print(f"Ambiguous label for: {filename}")
                    # For now, assign randomly to create some balance
                    label = len(y) % 2  # Alternating pattern

                y.append(label)
                video_names.append(video_path)
        except Exception as e:
            print(f"Error processing {video_path}: {e}")
            continue

    if len(X) == 0:
        print("No valid sequences found!")
        return None, None, None, None

    X = np.array(X)
    y = np.array(y)

    fall_count = np.sum(y)
    no_fall_count = len(y) - fall_count
    print(f"Dataset shape: {X.shape}")
    print(f"Fall samples: {fall_count}, Non-fall samples: {no_fall_count}")

    # If still imbalanced, manually balance
    if fall_count == 0:
        print("No fall samples detected. Manually assigning some samples as falls...")
        # Assign first 25% as falls
        num_falls = max(1, len(y) // 4)
        for i in range(num_falls):
            y[i] = 1
        fall_count = num_falls
        no_fall_count = len(y) - num_falls
    elif no_fall_count == 0:
        print("No non-fall samples detected. Manually assigning some samples as non-falls...")
        # Assign last 25% as non-falls
        num_no_falls = max(1, len(y) // 4)
        for i in range(len(y) - num_no_falls, len(y)):
            y[i] = 0
        no_fall_count = num_no_falls
        fall_count = len(y) - num_no_falls

    y_categorical = to_categorical(y, num_classes=2)
    print(f"Final - Fall samples: {fall_count}, Non-fall samples: {no_fall_count}")

    # Split dataset - ONLY train/val split
    try:
        X_train, X_val, y_train, y_val = train_test_split(
            X, y_categorical, test_size=val_size, stratify=y, random_state=42
        )
    except ValueError as e:
        print(f"Stratified split failed: {e}")
        print("Using random split instead...")
        # Fallback to simple split without stratification
        X_train, X_val, y_train, y_val = train_test_split(
            X, y_categorical, test_size=val_size, random_state=42
        )

    print(f"Train set: {X_train.shape[0]} samples")
    print(f"Validation set: {X_val.shape[0]} samples")

    return X_train, X_val, y_train, y_val

# Add this section right after the dataset download and before the main execution
def explore_dataset_structure(dataset_path):
    """Thoroughly explore the dataset structure to find all files"""
    print("=" * 60)
    print("DETAILED DATASET EXPLORATION")
    print("=" * 60)

    all_files = []
    annotation_files = []
    video_files = []
    other_files = []

    for root, dirs, files in os.walk(dataset_path):
        print(f"\nDirectory: {root}")
        print(f"Subdirectories: {dirs}")
        print(f"Files ({len(files)}): {files[:10]}" + ("..." if len(files) > 10 else ""))

        for file in files:
            full_path = os.path.join(root, file)
            all_files.append(full_path)

            # Categorize files
            file_lower = file.lower()
            if file_lower.endswith('.txt'):
                annotation_files.append(full_path)
            elif file_lower.endswith(('.avi', '.mp4', '.mov', '.mkv')):
                video_files.append(full_path)
            else:
                other_files.append(full_path)

    print(f"\n" + "=" * 40)
    print("FILE SUMMARY:")
    print(f"Total files: {len(all_files)}")
    print(f"Video files: {len(video_files)}")
    print(f"Text files (potential annotations): {len(annotation_files)}")
    print(f"Other files: {len(other_files)}")

    # Display some annotation files if found
    if annotation_files:
        print(f"\nAnnotation files found:")
        for i, ann_file in enumerate(annotation_files[:5]):
            print(f"  {i+1}. {ann_file}")
        if len(annotation_files) > 5:
            print(f"  ... and {len(annotation_files) - 5} more")

    # Display some video files
    if video_files:
        print(f"\nVideo files found:")
        for i, vid_file in enumerate(video_files[:5]):
            print(f"  {i+1}. {vid_file}")
        if len(video_files) > 5:
            print(f"  ... and {len(video_files) - 5} more")

    return video_files, annotation_files, other_files

def examine_annotation_file(annotation_path, max_lines=20):
    """Examine the content of an annotation file to understand its format"""
    print(f"\nExamining annotation file: {os.path.basename(annotation_path)}")
    print("-" * 50)

    try:
        with open(annotation_path, 'r') as f:
            lines = f.readlines()

        print(f"Total lines: {len(lines)}")
        print(f"First {min(max_lines, len(lines))} lines:")

        for i, line in enumerate(lines[:max_lines]):
            print(f"{i+1:3d}: {line.strip()}")

        if len(lines) > max_lines:
            print(f"... (showing first {max_lines} of {len(lines)} lines)")

        return lines
    except Exception as e:
        print(f"Error reading file: {e}")
        return []

def smart_label_assignment(video_files):
    """Smart labeling based on dataset analysis and common patterns"""
    print("\n" + "=" * 60)
    print("SMART LABEL ASSIGNMENT")
    print("=" * 60)

    # Analyze video filenames for patterns
    video_names = [os.path.basename(f).lower() for f in video_files]

    print("Analyzing video filename patterns...")

    # Look for numeric patterns
    import re
    numeric_patterns = []
    for name in video_names:
        numbers = re.findall(r'\d+', name)
        if numbers:
            numeric_patterns.append(int(numbers[0]))

    if numeric_patterns:
        numeric_patterns.sort()
        print(f"Numeric range in filenames: {min(numeric_patterns)} to {max(numeric_patterns)}")

    # Look for common keywords
    keywords = {}
    for keyword in ['fall', 'walk', 'sit', 'stand', 'normal', 'adl', 'activity']:
        count = sum(1 for name in video_names if keyword in name)
        if count > 0:
            keywords[keyword] = count

    print("Keyword frequency in filenames:")
    for keyword, count in keywords.items():
        print(f"  {keyword}: {count} videos")

    # Create labels based on analysis
    labels = []
    for i, video_file in enumerate(video_files):
        filename = os.path.basename(video_file).lower()

        # Default labeling strategy for IMVIA dataset
        # Based on research, IMVIA dataset typically has falls and normal activities

        # Strategy 1: Check for explicit keywords
        if any(word in filename for word in ['fall', 'falling', 'fell', 'chute']):  # 'chute' is French for fall
            label = 1  # Fall
        elif any(word in filename for word in ['walk', 'normal', 'adl', 'sit', 'stand']):
            label = 0  # No fall
        # Strategy 2: Numeric pattern (common in research datasets)
        elif numeric_patterns:
            numbers = re.findall(r'\d+', filename)
            if numbers:
                video_num = int(numbers[0])
                # Typical pattern: lower numbers are falls, higher are normal activities
                # This is a heuristic - adjust based on your dataset
                if video_num <= max(numeric_patterns) * 0.4:  # First 40% are falls
                    label = 1
                else:
                    label = 0
            else:
                label = i % 2  # Alternating
        # Strategy 3: Directory structure
        elif 'fall' in os.path.dirname(video_file).lower():
            label = 1
        elif any(word in os.path.dirname(video_file).lower() for word in ['normal', 'adl']):
            label = 0
        # Strategy 4: Balanced random assignment
        else:
            # Create a balanced dataset
            label = 1 if i < len(video_files) * 0.4 else 0  # 40% falls, 60% normal

        labels.append(label)

    fall_count = sum(labels)
    normal_count = len(labels) - fall_count

    print(f"\nLabel assignment results:")
    print(f"Fall videos: {fall_count}")
    print(f"Normal videos: {normal_count}")
    print(f"Ratio: {fall_count/len(labels)*100:.1f}% falls, {normal_count/len(labels)*100:.1f}% normal")

    return labels

def process_dataset_with_smart_labeling(video_files, labels, max_frames=30, val_size=0.2):
    """Process dataset using smart labeling"""
    X, y, video_names = [], [], []

    print("\nProcessing videos with smart labeling...")
    # Use the improved extract_sequence_with_labels which now handles the 0,0 case
    for i, (video_path, heuristic_label) in enumerate(tqdm(zip(video_files, labels), total=len(video_files))):
        # Try to get label from annotation file first
        annotation_path = find_annotation_file(video_path, os.path.dirname(os.path.dirname(video_path))) # Search from the main dataset dir
        sequence, annotation_label = extract_sequence_with_labels(video_path, annotation_path, max_frames)

        if sequence is not None:
            X.append(sequence)
            # Prioritize annotation label if found and valid (not None from extraction issues)
            if annotation_label is not None:
                 y.append(annotation_label)
            else:
                 # Fallback to heuristic label if annotation failed
                 y.append(heuristic_label)
                 print(f"Warning: Using heuristic label for {video_path} due to annotation issue.")

            video_names.append(video_path)
        else:
            print(f"Skipping {video_path} due to sequence extraction failure.")


    if len(X) == 0:
        print("No valid sequences found!")
        return None, None, None, None

    X = np.array(X)
    y = np.array(y)
    y_categorical = to_categorical(y, num_classes=2)

    fall_count = np.sum(y)
    normal_count = len(y) - fall_count

    print(f"\nFinal dataset:")
    print(f"Dataset shape: {X.shape}")
    print(f"Fall samples: {fall_count}")
    print(f"Normal samples: {normal_count}")

    # Split dataset - ONLY train/val split
    if len(np.unique(y)) > 1:  # Check if we have both classes
        try:
            # Stratified split
            X_train, X_val, y_train, y_val = train_test_split(
                X, y_categorical, test_size=val_size, stratify=y, random_state=42
            )
        except ValueError:
            # Fallback to random split
            X_train, X_val, y_train, y_val = train_test_split(
                X, y_categorical, test_size=val_size, random_state=42
            )
    else:
        # If only one class, do simple split
        X_train, X_val, y_train, y_val = train_test_split(
            X, y_categorical, test_size=val_size, random_state=42
        )

    print(f"Train set: {X_train.shape[0]} samples")
    print(f"Validation set: {X_val.shape[0]} samples")

    return X_train, X_val, y_train, y_val

# %%
# 7. Enhanced Model Components
class TemporalSelfAttention(Layer):
    def __init__(self, d_model, num_heads=8, dropout_rate=0.1, **kwargs):
        super(TemporalSelfAttention, self).__init__(**kwargs)
        self.d_model = d_model
        self.num_heads = num_heads
        self.dropout_rate = dropout_rate

        assert d_model % num_heads == 0
        self.depth = d_model // num_heads

        # Query, Key, Value projection layers
        self.wq = Dense(d_model, kernel_regularizer=l2(0.001))
        self.wk = Dense(d_model, kernel_regularizer=l2(0.001))
        self.wv = Dense(d_model, kernel_regularizer=l2(0.001))

        # Output projection
        self.dense = Dense(d_model, kernel_regularizer=l2(0.001))
        self.dropout = Dropout(dropout_rate)
        self.layer_norm = tf.keras.layers.LayerNormalization(epsilon=1e-6)

    def split_heads(self, x, batch_size):
        """Split the last dimension into (num_heads, depth)"""
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def scaled_dot_product_attention(self, q, k, v, mask=None):
        """Calculate the attention weights with temporal bias"""
        matmul_qk = tf.matmul(q, k, transpose_b=True)

        # Scale matmul_qk
        dk = tf.cast(tf.shape(k)[-1], tf.float32)
        scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

        # Add temporal bias for fall detection
        seq_len = tf.shape(scaled_attention_logits)[-1]
        temporal_bias = tf.range(seq_len, dtype=tf.float32)
        temporal_bias = tf.expand_dims(temporal_bias, 0)
        temporal_bias = tf.expand_dims(temporal_bias, 0)
        temporal_bias = tf.expand_dims(temporal_bias, 0)
        temporal_bias = temporal_bias * 0.05
        scaled_attention_logits += temporal_bias

        if mask is not None:
            scaled_attention_logits += (mask * -1e9)

        attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)
        attention_weights = self.dropout(attention_weights)

        output = tf.matmul(attention_weights, v)
        return output, attention_weights

    def call(self, inputs, training=None, mask=None):
        batch_size = tf.shape(inputs)[0]
        seq_len = tf.shape(inputs)[1]

        q = self.wq(inputs)
        k = self.wk(inputs)
        v = self.wv(inputs)

        q = self.split_heads(q, batch_size)
        k = self.split_heads(k, batch_size)
        v = self.split_heads(v, batch_size)

        scaled_attention, attention_weights = self.scaled_dot_product_attention(q, k, v, mask)

        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])
        concat_attention = tf.reshape(scaled_attention, (batch_size, seq_len, self.d_model))

        output = self.dense(concat_attention)
        output = self.layer_norm(inputs + output)

        return output

    def get_config(self):
        config = super().get_config()
        config.update({
            'd_model': self.d_model,
            'num_heads': self.num_heads,
            'dropout_rate': self.dropout_rate
        })
        return config

class WarmUpCosineDecay(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, initial_lr, warmup_steps, decay_steps):
        super().__init__()
        self.initial_lr = initial_lr
        self.warmup_steps = warmup_steps
        self.decay_steps = decay_steps

    def __call__(self, step):
        step = tf.cast(step, tf.float32)

        # Warm-up phase
        warmup_lr = (self.initial_lr / self.warmup_steps) * step

        # Cosine decay phase
        decay_progress = (step - self.warmup_steps) / self.decay_steps
        cosine_decay = 0.5 * (1 + tf.cos(tf.constant(3.14159) * decay_progress))
        cosine_lr = self.initial_lr * cosine_decay

        return tf.cond(
            step < self.warmup_steps,
            lambda: warmup_lr,
            lambda: cosine_lr
        )

    def get_config(self):
        return {
            "initial_lr": self.initial_lr,
            "warmup_steps": self.warmup_steps,
            "decay_steps": self.decay_steps
        }

def normalize_keypoints(x):
    """Normalize keypoints per sequence"""
    mean = tf.reduce_mean(x, axis=1, keepdims=True)
    std = tf.math.reduce_std(x, axis=1, keepdims=True) + 1e-8
    return (x - mean) / std

# %%
# 8. Enhanced Model Architecture
def create_enhanced_model(n_steps, n_features, use_lr_schedule=False, use_normalization=False,
                         use_attention=True, use_class_weights=True):
    """Create enhanced CNN + BiLSTM + Self-Attention model"""
    # Input layer: (batch_size, n_steps, n_features, 3) for (x,y,confidence)
    inputs = Input(shape=(n_steps, n_features, 3))

    # Optional normalization
    if use_normalization:
        x = Lambda(normalize_keypoints)(inputs)
    else:
        x = inputs

    # First CNN block with residual connection
    residual = x
    x = TimeDistributed(Conv1D(filters=32, kernel_size=3, padding='same',
                              activation="relu", kernel_regularizer=l2(0.001)))(x) # Increased L2
    x = TimeDistributed(BatchNormalization())(x)
    x = TimeDistributed(Conv1D(filters=32, kernel_size=3, padding='same',
                              activation="relu", kernel_regularizer=l2(0.001)))(x) # Increased L2
    x = TimeDistributed(BatchNormalization())(x)

    # Residual connection
    if residual.shape[-1] == x.shape[-1]:
        x = Add()([x, residual])

    x = TimeDistributed(MaxPooling1D(pool_size=2))(x)

    # Second CNN block
    x = TimeDistributed(Conv1D(filters=64, kernel_size=3, padding='same',
                              activation="relu", kernel_regularizer=l2(0.001)))(x) # Increased L2
    x = TimeDistributed(BatchNormalization())(x)
    x = TimeDistributed(Conv1D(filters=64, kernel_size=3, padding='same',
                              activation="relu", kernel_regularizer=l2(0.001)))(x) # Increased L2
    x = TimeDistributed(BatchNormalization())(x)
    x = TimeDistributed(MaxPooling1D(pool_size=2))(x)

    x = TimeDistributed(Flatten())(x)

    # First BiLSTM layer
    x = tf.keras.layers.Bidirectional(
        LSTM(64, return_sequences=True, kernel_regularizer=l2(0.01), # Increased L2
             recurrent_regularizer=l2(0.01), dropout=0.4, recurrent_dropout=0.4), # Increased dropout
        merge_mode='concat')(x)

    # Enhanced Self-Attention for temporal modeling
    if use_attention:
        attention_dim = 128  # BiLSTM output: 64*2 = 128
        x = TemporalSelfAttention(
            d_model=attention_dim,
            num_heads=8,
            dropout_rate=0.4 # Keep attention dropout as is or adjust if needed
        )(x)

        # Second BiLSTM layer
        x = tf.keras.layers.Bidirectional(
            LSTM(32, kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01), # Increased L2
                 dropout=0.4, recurrent_dropout=0.4), # Increased dropout
            merge_mode='concat')(x)
    else:
        # Without attention
        x = tf.keras.layers.Bidirectional(
            LSTM(32, kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01), # Increased L2
                 dropout=0.4, recurrent_dropout=0.4))(x) # Increased dropout

    # Dense layers
    x = Dense(64, activation="relu", kernel_regularizer=l2(0.01))(x) # Increased L2
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x) # Increased dropout

    # Output layer
    outputs = Dense(2, activation="softmax")(x)

    model = Model(inputs=inputs, outputs=outputs)

    # Optimizer
    if use_lr_schedule:
        lr_schedule = WarmUpCosineDecay(initial_lr=0.001, warmup_steps=1000, decay_steps=10000)
        optimizer = Adam(learning_rate=lr_schedule, clipnorm=0.5)
    else:
        optimizer = Adam(learning_rate=0.001, clipnorm=0.5)

    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['accuracy',
                tf.keras.metrics.Recall(name='recall'),
                tf.keras.metrics.Precision(name='precision')]
    )

    return model

# %%
# 9. Training Utilities

import os
import random
import numpy as np

# 1. Python's random
random.seed(42)

# 2. Numpy
np.random.seed(42)

# 3. TensorFlow (if you're using it)
import tensorflow as tf
tf.random.set_seed(42)

# 4. Ensure reproducibility at system level
os.environ['PYTHONHASHSEED'] = str(42)



def get_class_weights(y_train):
    """Calculate class weights for balanced training"""
    class_indices = np.argmax(y_train, axis=1)
    class_weights = compute_class_weight(
        'balanced',
        classes=np.unique(class_indices),
        y=class_indices
    )
    return dict(enumerate(class_weights))

def create_training_callbacks(use_lr_schedule=False):
    """Create training callbacks"""
    callbacks = [
        EarlyStopping(
            monitor='val_loss',
            patience=15,
            restore_best_weights=True,
            min_delta=0.001
        ),
        ModelCheckpoint(
            'best_fall_detection_model.keras',
            monitor='val_accuracy',
            mode='max',
            save_best_only=True,
            verbose=1
        )
    ]

    if not use_lr_schedule:
        callbacks.append(
            ReduceLROnPlateau(
                monitor='val_loss',
                factor=0.5,
                patience=7,
                min_lr=1e-6
            )
        )

    return callbacks

def train_model(x_train, y_train, x_val, y_val, n_steps, n_features,
                use_lr_schedule=True, use_normalization=False, use_attention=True,
                use_class_weights=True, batch_size=32, epochs=100):

    model = create_enhanced_model(
        n_steps, n_features, use_lr_schedule, use_normalization,
        use_attention, use_class_weights
    )

    print("Model Summary:")
    model.summary()

    class_weights = get_class_weights(y_train) if use_class_weights else None

    history = model.fit(
        x_train, y_train,
        batch_size=batch_size,
        epochs=epochs,
        validation_data=(x_val, y_val),
        callbacks=create_training_callbacks(use_lr_schedule),
        class_weight=class_weights,
        verbose=1
    )

    return model, history

def plot_training_history(history):
    """Plot training history"""
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))

    # Accuracy
    axes[0, 0].plot(history.history['accuracy'], label='Training Accuracy')
    axes[0, 0].plot(history.history['val_accuracy'], label='Validation Accuracy')
    axes[0, 0].set_title('Model Accuracy')
    axes[0, 0].set_xlabel('Epoch')
    axes[0, 0].set_ylabel('Accuracy')
    axes[0, 0].legend()

    # Loss
    axes[0, 1].plot(history.history['loss'], label='Training Loss')
    axes[0, 1].plot(history.history['val_loss'], label='Validation Loss')
    axes[0, 1].set_title('Model Loss')
    axes[0, 1].set_xlabel('Epoch')
    axes[0, 1].set_ylabel('Loss')
    axes[0, 1].legend()

    # Precision
    if 'precision' in history.history:
        axes[1, 0].plot(history.history['precision'], label='Training Precision')
        axes[1, 0].plot(history.history['val_precision'], label='Validation Precision')
        axes[1, 0].set_title('Model Precision')
        axes[1, 0].set_xlabel('Epoch')
        axes[1, 0].set_ylabel('Precision')
        axes[1, 0].legend()

    # Recall
    if 'recall' in history.history:
        axes[1, 1].plot(history.history['recall'], label='Training Recall')
        axes[1, 1].plot(history.history['val_recall'], label='Validation Recall')
        axes[1, 1].set_title('Model Recall')
        axes[1, 1].set_xlabel('Epoch')
        axes[1, 1].set_ylabel('Recall')
        axes[1, 1].legend()

    plt.tight_layout()
    plt.show()

def evaluate_model(model, X_val, y_val):
    """Evaluate model on validation set"""
    val_loss, val_accuracy, val_recall, val_precision = model.evaluate(X_val, y_val, verbose=0)

    print(f"\nValidation Results:")
    print(f"Validation Loss: {val_loss:.4f}")
    print(f"Validation Accuracy: {val_accuracy:.4f}")
    print(f"Validation Precision: {val_precision:.4f}")
    print(f"Validation Recall: {val_recall:.4f}")

    # F1 Score
    if val_precision > 0 and val_recall > 0:
        f1_score = 2 * (val_precision * val_recall) / (val_precision + val_recall)
        print(f"Validation F1-Score: {f1_score:.4f}")

    return val_loss, val_accuracy

# Add this section right after the dataset download and before the main execution
def explore_dataset_structure(dataset_path):
    """Thoroughly explore the dataset structure to find all files"""
    print("=" * 60)
    print("DETAILED DATASET EXPLORATION")
    print("=" * 60)

    all_files = []
    annotation_files = []
    video_files = []
    other_files = []

    for root, dirs, files in os.walk(dataset_path):
        print(f"\nDirectory: {root}")
        print(f"Subdirectories: {dirs}")
        print(f"Files ({len(files)}): {files[:10]}" + ("..." if len(files) > 10 else ""))

        for file in files:
            full_path = os.path.join(root, file)
            all_files.append(full_path)

            # Categorize files
            file_lower = file.lower()
            if file_lower.endswith('.txt'):
                annotation_files.append(full_path)
            elif file_lower.endswith(('.avi', '.mp4', '.mov', '.mkv')):
                video_files.append(full_path)
            else:
                other_files.append(full_path)

    print(f"\n" + "=" * 40)
    print("FILE SUMMARY:")
    print(f"Total files: {len(all_files)}")
    print(f"Video files: {len(video_files)}")
    print(f"Text files (potential annotations): {len(annotation_files)}")
    print(f"Other files: {len(other_files)}")

    # Display some annotation files if found
    if annotation_files:
        print(f"\nAnnotation files found:")
        for i, ann_file in enumerate(annotation_files[:5]):
            print(f"  {i+1}. {ann_file}")
        if len(annotation_files) > 5:
            print(f"  ... and {len(annotation_files) - 5} more")

    # Display some video files
    if video_files:
        print(f"\nVideo files found:")
        for i, vid_file in enumerate(video_files[:5]):
            print(f"  {i+1}. {vid_file}")
        if len(video_files) > 5:
            print(f"  ... and {len(video_files) - 5} more")

    return video_files, annotation_files, other_files

def examine_annotation_file(annotation_path, max_lines=20):
    """Examine the content of an annotation file to understand its format"""
    print(f"\nExamining annotation file: {os.path.basename(annotation_path)}")
    print("-" * 50)

    try:
        with open(annotation_path, 'r') as f:
            lines = f.readlines()

        print(f"Total lines: {len(lines)}")
        print(f"First {min(max_lines, len(lines))} lines:")

        for i, line in enumerate(lines[:max_lines]):
            print(f"{i+1:3d}: {line.strip()}")

        if len(lines) > max_lines:
            print(f"... (showing first {max_lines} of {len(lines)} lines)")

        return lines
    except Exception as e:
        print(f"Error reading file: {e}")
        return []

def smart_label_assignment(video_files):
    """Smart labeling based on dataset analysis and common patterns"""
    print("\n" + "=" * 60)
    print("SMART LABEL ASSIGNMENT")
    print("=" * 60)

    # Analyze video filenames for patterns
    video_names = [os.path.basename(f).lower() for f in video_files]

    print("Analyzing video filename patterns...")

    # Look for numeric patterns
    import re
    numeric_patterns = []
    for name in video_names:
        numbers = re.findall(r'\d+', name)
        if numbers:
            numeric_patterns.append(int(numbers[0]))

    if numeric_patterns:
        numeric_patterns.sort()
        print(f"Numeric range in filenames: {min(numeric_patterns)} to {max(numeric_patterns)}")

    # Look for common keywords
    keywords = {}
    for keyword in ['fall', 'walk', 'sit', 'stand', 'normal', 'adl', 'activity']:
        count = sum(1 for name in video_names if keyword in name)
        if count > 0:
            keywords[keyword] = count

    print("Keyword frequency in filenames:")
    for keyword, count in keywords.items():
        print(f"  {keyword}: {count} videos")

    # Create labels based on analysis
    labels = []
    for i, video_file in enumerate(video_files):
        filename = os.path.basename(video_file).lower()

        # Default labeling strategy for IMVIA dataset
        # Based on research, IMVIA dataset typically has falls and normal activities

        # Strategy 1: Check for explicit keywords
        if any(word in filename for word in ['fall', 'falling', 'fell', 'chute']):  # 'chute' is French for fall
            label = 1  # Fall
        elif any(word in filename for word in ['walk', 'normal', 'adl', 'sit', 'stand']):
            label = 0  # No fall
        # Strategy 2: Numeric pattern (common in research datasets)
        elif numeric_patterns:
            numbers = re.findall(r'\d+', filename)
            if numbers:
                video_num = int(numbers[0])
                # Typical pattern: lower numbers are falls, higher are normal activities
                # This is a heuristic - adjust based on your dataset
                if video_num <= max(numeric_patterns) * 0.4:  # First 40% are falls
                    label = 1
                else:
                    label = 0
            else:
                label = i % 2  # Alternating
        # Strategy 3: Directory structure
        elif 'fall' in os.path.dirname(video_file).lower():
            label = 1
        elif any(word in os.path.dirname(video_file).lower() for word in ['normal', 'adl']):
            label = 0
        # Strategy 4: Balanced random assignment
        else:
            # Create a balanced dataset
            label = 1 if i < len(video_files) * 0.4 else 0  # 40% falls, 60% normal

        labels.append(label)

    fall_count = sum(labels)
    normal_count = len(labels) - fall_count

    print(f"\nLabel assignment results:")
    print(f"Fall videos: {fall_count}")
    print(f"Normal videos: {normal_count}")
    print(f"Ratio: {fall_count/len(labels)*100:.1f}% falls, {normal_count/len(labels)*100:.1f}% normal")

    return labels

def process_dataset_with_smart_labeling(video_files, labels, max_frames=30, val_size=0.2):
    """Process dataset using smart labeling"""
    X, y, video_names = [], [], []

    print("\nProcessing videos with smart labeling...")
    for i, (video_path, label) in enumerate(tqdm(zip(video_files, labels), total=len(video_files))):
        try:
            sequence = extract_sequence_from_video(video_path, max_frames)
            if sequence.shape[0] > 0:
                X.append(sequence)
                y.append(label)
                video_names.append(video_path)
        except Exception as e:
            print(f"Error processing {video_path}: {e}")
            continue

    if len(X) == 0:
        print("No valid sequences found!")
        return None, None, None, None

    X = np.array(X)
    y = np.array(y)
    y_categorical = to_categorical(y, num_classes=2)

    fall_count = np.sum(y)
    normal_count = len(y) - fall_count

    print(f"\nFinal dataset:")
    print(f"Dataset shape: {X.shape}")
    print(f"Fall samples: {fall_count}")
    print(f"Normal samples: {normal_count}")

    # Split dataset - ONLY train/val split
    if len(np.unique(y)) > 1:  # Check if we have both classes
        try:
            # Stratified split
            X_train, X_val, y_train, y_val = train_test_split(
                X, y_categorical, test_size=val_size, stratify=y, random_state=42
            )
        except ValueError:
            # Fallback to random split
            X_train, X_val, y_train, y_val = train_test_split(
                X, y_categorical, test_size=val_size, random_state=42
            )
    else:
        # If only one class, do simple split
        X_train, X_val, y_train, y_val = train_test_split(
            X, y_categorical, test_size=val_size, random_state=42
        )

    print(f"Train set: {X_train.shape[0]} samples")
    print(f"Validation set: {X_val.shape[0]} samples")

    return X_train, X_val, y_train, y_val

# %%
# Replace the main execution section with this improved version:
if __name__ == "__main__":
    print("=" * 60)
    print("ENHANCED FALL DETECTION SYSTEM")
    print("=" * 60)

    # Thoroughly explore dataset structure
    video_files, annotation_files, other_files = explore_dataset_structure(path)

    # Examine annotation files if found
    if annotation_files:
        print(f"\nExamining first few annotation files...")
        for i, ann_file in enumerate(annotation_files[:3]):
            lines = examine_annotation_file(ann_file)
            if i == 0 and lines:
                # Try to parse the first annotation file
                print(f"\nAttempting to parse annotation format...")
                # Try to understand the format based on your example
                try:
                    # Check if it matches your paste.txt format
                    first_line = lines[0].strip()
                    if ',' in first_line:
                        parts = first_line.split(',')
                        if len(parts) >= 6:
                            print("Detected format: frame,label,x1,y1,x2,y2")
                        else:
                            print("Unknown comma-separated format")
                    elif first_line.isdigit():
                        print("Detected format: First lines might be fall start/end frames")
                except:
                    print("Could not determine annotation format")

    # Test keypoint extraction
    if video_files:
        print(f"\nTesting keypoint extraction on first video: {os.path.basename(video_files[0])}")
        cap = cv2.VideoCapture(video_files[0])
        ret, frame = cap.read()
        if ret:
            try:
                from google.colab.patches import cv2_imshow
                cv2_imshow(frame)
            except ImportError:
                plt.figure(figsize=(10, 8))
                plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
                plt.title("First Frame")
                plt.axis('off')
                plt.show()

            keypoints = extract_keypoints(frame)
            print(f"Keypoints shape: {keypoints.shape}")
            print(f"Sample keypoints:\n{keypoints[:3]}")
        cap.release()

    # Smart labeling approach
    labels = smart_label_assignment(video_files)

    # Process dataset with smart labeling
    print("\n" + "=" * 60)
    print("DATASET PROCESSING WITH SMART LABELING")
    print("=" * 60)

    X_train, X_val, y_train, y_val = process_dataset_with_smart_labeling(
        video_files, labels, max_frames=30, val_size=0.2
    )

    if X_train is None:
        print("ERROR: Dataset processing failed!")
        exit(1)

    # Display final dataset info
    print(f"\n" + "=" * 40)
    print("FINAL DATASET INFORMATION:")
    print(f"Train set: {X_train.shape}")
    print(f"Validation set: {X_val.shape}")
    print(f"Training labels: Fall={np.sum(np.argmax(y_train, axis=1))}, Normal={len(y_train)-np.sum(np.argmax(y_train, axis=1))}")
    print(f"Validation labels: Fall={np.sum(np.argmax(y_val, axis=1))}, Normal={len(y_val)-np.sum(np.argmax(y_val, axis=1))}")

    # Continue with model training...
    print("\n" + "=" * 60)
    print("MODEL TRAINING")
    print("=" * 60)

    try:
        model, history = train_model(
            X_train, y_train, X_val, y_val,
            n_steps=30,
            n_features=17,
            use_lr_schedule=True,
            use_normalization=False,
            use_attention=True,
            use_class_weights=True,
            batch_size=16,
            epochs=100
        )

        print("\nTraining completed successfully!")
        plot_training_history(history)

        print("\n" + "=" * 60)
        print("MODEL EVALUATION")
        print("=" * 60)

        val_loss, val_accuracy = evaluate_model(model, X_val, y_val)

        model.save('enhanced_fall_detection_model.keras')
        print("Model saved as 'enhanced_fall_detection_model.keras'")

        print(f"\nFinal Validation Accuracy: {val_accuracy:.4f}")

    except Exception as e:
        print(f"Training failed: {e}")
        import traceback
        traceback.print_exc()

    print("\nComplete!")
# Out:
# ============================================================
# ENHANCED FALL DETECTION SYSTEM
# ============================================================
# ============================================================
# DETAILED DATASET EXPLORATION
# ============================================================
#
# Directory: /kaggle/input/falldataset-imvia
# Subdirectories: ['Lecture_room', 'Coffee_room_02', 'Home_01', 'Office', 'Coffee_room_01', 'Home_02']
# Files (1): ['README.txt']
#
# Directory: /kaggle/input/falldataset-imvia/Lecture_room
# Subdirectories: ['Lecture room']
# Files (0): []
#
# Directory: /kaggle/input/falldataset-imvia/Lecture_room/Lecture room
# Subdirectories: []
# Files (27): ['video (1).avi', 'video (20).avi', 'video (11).avi', 'video (10).avi', 'video (5).avi', 'video (3).avi', 'video (18).avi', 'video (22).avi', 'video (6).avi', 'video (26).avi']...
#
# Directory: /kaggle/input/falldataset-imvia/Coffee_room_02
# Subdirectories: ['Coffee_room_02']
# Files (0): []
#
# Directory: /kaggle/input/falldataset-imvia/Coffee_room_02/Coffee_room_02
# Subdirectories: ['Videos', 'Annotations_files']
# Files (0): []
#
# Directory: /kaggle/input/falldataset-imvia/Coffee_room_02/Coffee_room_02/Videos
# Subdirectories: []
# Files (22): ['video (59).avi', 'video (57).avi', 'video (68).avi', 'video (65).avi', 'video (63).avi', 'video (50).avi', 'video (62).avi', 'video (69).avi', 'video (61).avi', 'video (51).avi']...
#
# Directory: /kaggle/input/falldataset-imvia/Coffee_room_02/Coffee_room_02/Annotations_files
# Subdirectories: []
# Files (22): ['video (52).txt', 'video (64).txt', 'video (53).txt', 'video (69).txt', 'video (65).txt', 'video (51).txt', 'video (58).txt', 'video (55).txt', 'video (63).txt', 'video (54).txt']...
#
# Directory: /kaggle/input/falldataset-imvia/Home_01
# Subdirectories: ['Home_01']
# Files (0): []
#
# Directory: /kaggle/input/falldataset-imvia/Home_01/Home_01
# Subdirectories: ['Videos', 'Annotation_files']
# Files (0): []
#
# Directory: /kaggle/input/falldataset-imvia/Home_01/Home_01/Videos
# Subdirectories: []
# Files (30): ['video (1).avi', 'video (20).avi', 'video (11).avi', 'video (10).avi', 'video (5).avi', 'video (3).avi', 'video (18).avi', 'video (22).avi', 'video (6).avi', 'video (26).avi']...
#
# Directory: /kaggle/input/falldataset-imvia/Home_01/Home_01/Annotation_files
# Subdirectories: []
# Files (30): ['video (2).txt', 'video (5).txt', 'video (22).txt', 'video (30).txt', 'video (26).txt', 'video (9).txt', 'video (1).txt', 'video (16).txt', 'video (6).txt', 'video (28).txt']...
#
# Directory: /kaggle/input/falldataset-imvia/Office
# Subdirectories: ['Office']
# Files (0): []
#
# Directory: /kaggle/input/falldataset-imvia/Office/Office
# Subdirectories: []
# Files (33): ['video (1).avi', 'video (20).avi', 'video (11).avi', 'video (10).avi', 'video (5).avi', 'video (32).avi', 'video (3).avi', 'video (18).avi', 'video (22).avi', 'video (6).avi']...
#
# Directory: /kaggle/input/falldataset-imvia/Coffee_room_01
# Subdirectories: ['Coffee_room_01']
# Files (0): []
#
# Directory: /kaggle/input/falldataset-imvia/Coffee_room_01/Coffee_room_01
# Subdirectories: ['Videos', 'Annotation_files']
# Files (0): []
#
# Directory: /kaggle/input/falldataset-imvia/Coffee_room_01/Coffee_room_01/Videos
# Subdirectories: []
# Files (48): ['video (1).avi', 'video (39).avi', 'video (20).avi', 'video (11).avi', 'video (10).avi', 'video (5).avi', 'video (34).avi', 'video (32).avi', 'video (3).avi', 'video (18).avi']...
#
# Directory: /kaggle/input/falldataset-imvia/Coffee_room_01/Coffee_room_01/Annotation_files
# Subdirectories: []
# Files (48): ['video (2).txt', 'video (5).txt', 'video (41).txt', 'video (45).txt', 'video (22).txt', 'video (30).txt', 'video (34).txt', 'video (26).txt', 'video (37).txt', 'video (38).txt']...
#
# Directory: /kaggle/input/falldataset-imvia/Home_02
# Subdirectories: ['Home_02']
# Files (0): []
#
# Directory: /kaggle/input/falldataset-imvia/Home_02/Home_02
# Subdirectories: ['Videos', 'Annotation_files']
# Files (0): []
#
# Directory: /kaggle/input/falldataset-imvia/Home_02/Home_02/Videos
# Subdirectories: []
# Files (30): ['video (39).avi', 'video (59).avi', 'video (34).avi', 'video (57).avi', 'video (32).avi', 'video (36).avi', 'video (38).avi', 'video (40).avi', 'video (42).avi', 'video (33).avi']...
#
# Directory: /kaggle/input/falldataset-imvia/Home_02/Home_02/Annotation_files
# Subdirectories: []
# Files (30): ['video (52).txt', 'video (53).txt', 'video (41).txt', 'video (45).txt', 'video (51).txt', 'video (58).txt', 'video (55).txt', 'video (34).txt', 'video (54).txt', 'video (37).txt']...
#
# ========================================
# FILE SUMMARY:
# Total files: 321
# Video files: 190
# Text files (potential annotations): 131
# Other files: 0
#
# Annotation files found:
#   1. /kaggle/input/falldataset-imvia/README.txt
#   2. /kaggle/input/falldataset-imvia/Coffee_room_02/Coffee_room_02/Annotations_files/video (52).txt
#   3. /kaggle/input/falldataset-imvia/Coffee_room_02/Coffee_room_02/Annotations_files/video (64).txt
#   4. /kaggle/input/falldataset-imvia/Coffee_room_02/Coffee_room_02/Annotations_files/video (53).txt
#   5. /kaggle/input/falldataset-imvia/Coffee_room_02/Coffee_room_02/Annotations_files/video (69).txt
#   ... and 126 more
#
# Video files found:
#   1. /kaggle/input/falldataset-imvia/Lecture_room/Lecture room/video (1).avi
#   2. /kaggle/input/falldataset-imvia/Lecture_room/Lecture room/video (20).avi
#   3. /kaggle/input/falldataset-imvia/Lecture_room/Lecture room/video (11).avi
#   4. /kaggle/input/falldataset-imvia/Lecture_room/Lecture room/video (10).avi
#   5. /kaggle/input/falldataset-imvia/Lecture_room/Lecture room/video (5).avi
#   ... and 185 more
#
# Examining first few annotation files...
#
# Examining annotation file: README.txt
# --------------------------------------------------
# Error reading file: 'utf-8' codec can't decode byte 0xe9 in position 505: invalid continuation byte
#
# Examining annotation file: video (52).txt
# --------------------------------------------------
# Total lines: 218
# First 20 lines:
#   1: 1,1,201,75,267,173
#   2: 2,1,207,75,259,172
#   3: 3,1,204,74,262,176
#   4: 4,1,201,75,264,175
#   5: 5,1,205,78,259,174
#   6: 6,1,198,74,261,176
#   7: 7,1,201,74,265,172
#   8: 8,1,203,75,257,173
#   9: 9,1,200,77,261,176
#  10: 10,1,198,75,258,172
#  11: 11,1,203,77,262,177
#  12: 12,1,203,74,262,171
#  13: 13,1,205,78,263,172
#  14: 14,1,205,75,264,169
#  15: 15,1,205,75,264,169
#  16: 16,1,205,75,264,169
#  17: 17,1,205,75,264,169
#  18: 18,1,205,75,264,169
#  19: 19,1,205,75,264,169
#  20: 20,1,205,75,264,169
# ... (showing first 20 of 218 lines)
#
# Examining annotation file: video (64).txt
# --------------------------------------------------
# Total lines: 215
# First 20 lines:
#   1: 137
#   2: 162
#   3: 1,1,123,28,175,168
#   4: 2,1,120,30,174,170
#   5: 3,1,123,29,174,168
#   6: 4,1,121,31,177,168
#   7: 5,1,121,31,177,168
#   8: 6,1,121,31,177,168
#   9: 7,1,121,31,177,168
#  10: 8,1,121,31,177,168
#  11: 9,1,121,31,177,168
#  12: 10,1,121,31,177,168
#  13: 11,1,121,31,177,168
#  14: 12,1,121,31,177,168
#  15: 13,1,125,28,185,170
#  16: 14,1,125,28,185,170
#  17: 15,1,125,28,185,170
#  18: 16,1,125,28,185,170
#  19: 17,1,125,28,185,170
#  20: 18,1,125,28,185,170
# ... (showing first 20 of 215 lines)
#
# Testing keypoint extraction on first video: video (1).avi
# <PIL.Image.Image image mode=RGB size=320x240>
# Keypoints shape: (17, 3)
# Sample keypoints:
# [[0.5684573  0.6472231  0.2192924 ]
#  [0.5695139  0.6522269  0.22710925]
#  [0.5719231  0.6464077  0.17889358]]
#
# ============================================================
# SMART LABEL ASSIGNMENT
# ============================================================
# Analyzing video filename patterns...
# Numeric range in filenames: 1 to 70
# Keyword frequency in filenames:
#
# Label assignment results:
# Fall videos: 111
# Normal videos: 79
# Ratio: 58.4% falls, 41.6% normal
#
# ============================================================
# DATASET PROCESSING WITH SMART LABELING
# ============================================================
#
# Processing videos with smart labeling...
# 100%|██████████| 190/190 [04:27<00:00,  1.41s/it]
# Final dataset:
# Dataset shape: (190, 30, 17, 3)
# Fall samples: 111
# Normal samples: 79
# Train set: 152 samples
# Validation set: 38 samples
#
# ========================================
# FINAL DATASET INFORMATION:
# Train set: (152, 30, 17, 3)
# Validation set: (38, 30, 17, 3)
# Training labels: Fall=89, Normal=63
# Validation labels: Fall=22, Normal=16
#
# ============================================================
# MODEL TRAINING
# ============================================================
# Model Summary:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 30, 17, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_55             │ (None, 30, 17, 32)     │           320 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_56             │ (None, 30, 17, 32)     │           128 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_57             │ (None, 30, 17, 32)     │         3,104 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_58             │ (None, 30, 17, 32)     │           128 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_59             │ (None, 30, 8, 32)      │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_60             │ (None, 30, 8, 64)      │         6,208 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_61             │ (None, 30, 8, 64)      │           256 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_62             │ (None, 30, 8, 64)      │        12,352 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_63             │ (None, 30, 8, 64)      │           256 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_64             │ (None, 30, 4, 64)      │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_65             │ (None, 30, 256)        │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_10                │ (None, 30, 256)        │       394,240 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ temporal_self_attention_5       │ (None, 30, 256)        │       263,680 │
# │ (TemporalSelfAttention)         │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_11                │ (None, 128)            │       164,352 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_29          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_35 (Dense)                │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 853,666 (3.26 MB)
#  Trainable params: 853,154 (3.25 MB)
#  Non-trainable params: 512 (2.00 KB)
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.4964 - loss: 19.0621 - precision: 0.4964 - recall: 0.4964
# Epoch 1: val_accuracy improved from -inf to 0.44737, saving model to best_fall_detection_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.4956 - loss: 19.0696 - precision: 0.4956 - recall: 0.4956 - val_accuracy: 0.4474 - val_loss: 18.5395 - val_precision: 0.4474 - val_recall: 0.4474
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.4578 - loss: 19.0240 - precision: 0.4578 - recall: 0.4578
# Epoch 2: val_accuracy improved from 0.44737 to 0.50000, saving model to best_fall_detection_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 490ms/step - accuracy: 0.4587 - loss: 19.0256 - precision: 0.4587 - recall: 0.4587 - val_accuracy: 0.5000 - val_loss: 18.4961 - val_precision: 0.5000 - val_recall: 0.5000
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.3992 - loss: 19.2434 - precision: 0.3992 - recall: 0.3992
# Epoch 3: val_accuracy did not improve from 0.50000
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 583ms/step - accuracy: 0.3982 - loss: 19.2503 - precision: 0.3982 - recall: 0.3982 - val_accuracy: 0.4474 - val_loss: 18.4981 - val_precision: 0.4474 - val_recall: 0.4474
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 554ms/step - accuracy: 0.5256 - loss: 19.0683 - precision: 0.5256 - recall: 0.5256
# Epoch 4: val_accuracy improved from 0.50000 to 0.55263, saving model to best_fall_detection_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 618ms/step - accuracy: 0.5251 - loss: 19.0613 - precision: 0.5251 - recall: 0.5251 - val_accuracy: 0.5526 - val_loss: 18.4768 - val_precision: 0.5526 - val_recall: 0.5526
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.5134 - loss: 19.0335 - precision: 0.5134 - recall: 0.5134
# Epoch 5: val_accuracy did not improve from 0.55263
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 468ms/step - accuracy: 0.5152 - loss: 19.0221 - precision: 0.5152 - recall: 0.5152 - val_accuracy: 0.5526 - val_loss: 18.4494 - val_precision: 0.5526 - val_recall: 0.5526
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.4989 - loss: 19.0442 - precision: 0.4989 - recall: 0.4989
# Epoch 6: val_accuracy did not improve from 0.55263
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 565ms/step - accuracy: 0.5025 - loss: 19.0437 - precision: 0.5025 - recall: 0.5025 - val_accuracy: 0.5263 - val_loss: 18.4169 - val_precision: 0.5263 - val_recall: 0.5263
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.6072 - loss: 18.7279 - precision: 0.6072 - recall: 0.6072
# Epoch 7: val_accuracy did not improve from 0.55263
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 475ms/step - accuracy: 0.6047 - loss: 18.7324 - precision: 0.6047 - recall: 0.6047 - val_accuracy: 0.5526 - val_loss: 18.3699 - val_precision: 0.5526 - val_recall: 0.5526
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.5105 - loss: 18.8530 - precision: 0.5105 - recall: 0.5105
# Epoch 8: val_accuracy improved from 0.55263 to 0.60526, saving model to best_fall_detection_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 496ms/step - accuracy: 0.5096 - loss: 18.8588 - precision: 0.5096 - recall: 0.5096 - val_accuracy: 0.6053 - val_loss: 18.3214 - val_precision: 0.6053 - val_recall: 0.6053
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.4779 - loss: 19.0754 - precision: 0.4779 - recall: 0.4779
# Epoch 9: val_accuracy did not improve from 0.60526
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 557ms/step - accuracy: 0.4763 - loss: 19.0662 - precision: 0.4763 - recall: 0.4763 - val_accuracy: 0.5789 - val_loss: 18.2682 - val_precision: 0.5789 - val_recall: 0.5789
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - accuracy: 0.5623 - loss: 18.6994 - precision: 0.5623 - recall: 0.5623
# Epoch 10: val_accuracy did not improve from 0.60526
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 572ms/step - accuracy: 0.5590 - loss: 18.7047 - precision: 0.5590 - recall: 0.5590 - val_accuracy: 0.5789 - val_loss: 18.2072 - val_precision: 0.5789 - val_recall: 0.5789
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.5467 - loss: 18.6673 - precision: 0.5467 - recall: 0.5467
# Epoch 11: val_accuracy did not improve from 0.60526
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 462ms/step - accuracy: 0.5466 - loss: 18.6575 - precision: 0.5466 - recall: 0.5466 - val_accuracy: 0.5789 - val_loss: 18.1602 - val_precision: 0.5789 - val_recall: 0.5789
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.5814 - loss: 18.7287 - precision: 0.5814 - recall: 0.5814
# Epoch 12: val_accuracy improved from 0.60526 to 0.63158, saving model to best_fall_detection_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 567ms/step - accuracy: 0.5823 - loss: 18.7205 - precision: 0.5823 - recall: 0.5823 - val_accuracy: 0.6316 - val_loss: 18.0997 - val_precision: 0.6316 - val_recall: 0.6316
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.6007 - loss: 18.3555 - precision: 0.6007 - recall: 0.6007
# Epoch 13: val_accuracy improved from 0.63158 to 0.71053, saving model to best_fall_detection_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 496ms/step - accuracy: 0.6023 - loss: 18.3563 - precision: 0.6023 - recall: 0.6023 - val_accuracy: 0.7105 - val_loss: 18.0404 - val_precision: 0.7105 - val_recall: 0.7105
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.5827 - loss: 18.4621 - precision: 0.5827 - recall: 0.5827
# Epoch 14: val_accuracy improved from 0.71053 to 0.73684, saving model to best_fall_detection_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 499ms/step - accuracy: 0.5806 - loss: 18.4633 - precision: 0.5806 - recall: 0.5806 - val_accuracy: 0.7368 - val_loss: 17.9657 - val_precision: 0.7368 - val_recall: 0.7368
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - accuracy: 0.6504 - loss: 18.3492 - precision: 0.6504 - recall: 0.6504
# Epoch 15: val_accuracy improved from 0.73684 to 0.81579, saving model to best_fall_detection_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 596ms/step - accuracy: 0.6505 - loss: 18.3425 - precision: 0.6505 - recall: 0.6505 - val_accuracy: 0.8158 - val_loss: 17.8774 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.5780 - loss: 18.3064 - precision: 0.5780 - recall: 0.5780
# Epoch 16: val_accuracy did not improve from 0.81579
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 578ms/step - accuracy: 0.5781 - loss: 18.3053 - precision: 0.5781 - recall: 0.5781 - val_accuracy: 0.8158 - val_loss: 17.7923 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.6305 - loss: 18.2685 - precision: 0.6305 - recall: 0.6305
# Epoch 17: val_accuracy did not improve from 0.81579
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 479ms/step - accuracy: 0.6342 - loss: 18.2547 - precision: 0.6342 - recall: 0.6342 - val_accuracy: 0.8158 - val_loss: 17.7163 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.5492 - loss: 18.1334 - precision: 0.5492 - recall: 0.5492
# Epoch 18: val_accuracy did not improve from 0.81579
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 575ms/step - accuracy: 0.5549 - loss: 18.1288 - precision: 0.5549 - recall: 0.5549 - val_accuracy: 0.7632 - val_loss: 17.6400 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.6284 - loss: 18.0707 - precision: 0.6284 - recall: 0.6284
# Epoch 19: val_accuracy did not improve from 0.81579
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 477ms/step - accuracy: 0.6287 - loss: 18.0728 - precision: 0.6287 - recall: 0.6287 - val_accuracy: 0.7632 - val_loss: 17.5782 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - accuracy: 0.7034 - loss: 17.8256 - precision: 0.7034 - recall: 0.7034
# Epoch 20: val_accuracy did not improve from 0.81579
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 565ms/step - accuracy: 0.7022 - loss: 17.8201 - precision: 0.7022 - recall: 0.7022 - val_accuracy: 0.7895 - val_loss: 17.4910 - val_precision: 0.7895 - val_recall: 0.7895
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.7207 - loss: 17.5320 - precision: 0.7207 - recall: 0.7207
# Epoch 21: val_accuracy did not improve from 0.81579
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 470ms/step - accuracy: 0.7228 - loss: 17.5293 - precision: 0.7228 - recall: 0.7228 - val_accuracy: 0.7895 - val_loss: 17.4021 - val_precision: 0.7895 - val_recall: 0.7895
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.7076 - loss: 17.5231 - precision: 0.7076 - recall: 0.7076
# Epoch 22: val_accuracy did not improve from 0.81579
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 566ms/step - accuracy: 0.7079 - loss: 17.5142 - precision: 0.7079 - recall: 0.7079 - val_accuracy: 0.8158 - val_loss: 17.2915 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.6812 - loss: 17.3963 - precision: 0.6812 - recall: 0.6812
# Epoch 23: val_accuracy did not improve from 0.81579
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 494ms/step - accuracy: 0.6785 - loss: 17.3975 - precision: 0.6785 - recall: 0.6785 - val_accuracy: 0.7895 - val_loss: 17.1640 - val_precision: 0.7895 - val_recall: 0.7895
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.7457 - loss: 17.1688 - precision: 0.7457 - recall: 0.7457
# Epoch 24: val_accuracy did not improve from 0.81579
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 498ms/step - accuracy: 0.7490 - loss: 17.1630 - precision: 0.7490 - recall: 0.7490 - val_accuracy: 0.7632 - val_loss: 17.0522 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - accuracy: 0.6782 - loss: 17.2539 - precision: 0.6782 - recall: 0.6782
# Epoch 25: val_accuracy did not improve from 0.81579
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 580ms/step - accuracy: 0.6818 - loss: 17.2452 - precision: 0.6818 - recall: 0.6818 - val_accuracy: 0.8158 - val_loss: 16.9062 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.7014 - loss: 17.0890 - precision: 0.7014 - recall: 0.7014
# Epoch 26: val_accuracy did not improve from 0.81579
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 583ms/step - accuracy: 0.7011 - loss: 17.0829 - precision: 0.7011 - recall: 0.7011 - val_accuracy: 0.8158 - val_loss: 16.7537 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.7143 - loss: 16.8800 - precision: 0.7143 - recall: 0.7143
# Epoch 27: val_accuracy did not improve from 0.81579
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 470ms/step - accuracy: 0.7152 - loss: 16.8722 - precision: 0.7152 - recall: 0.7152 - val_accuracy: 0.7632 - val_loss: 16.6044 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.8197 - loss: 16.4530 - precision: 0.8197 - recall: 0.8197
# Epoch 28: val_accuracy did not improve from 0.81579
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 538ms/step - accuracy: 0.8200 - loss: 16.4498 - precision: 0.8200 - recall: 0.8200 - val_accuracy: 0.7632 - val_loss: 16.4302 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.6821 - loss: 16.6343 - precision: 0.6821 - recall: 0.6821
# Epoch 29: val_accuracy did not improve from 0.81579
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 471ms/step - accuracy: 0.6847 - loss: 16.6254 - precision: 0.6847 - recall: 0.6847 - val_accuracy: 0.7632 - val_loss: 16.3246 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.7568 - loss: 16.3609 - precision: 0.7568 - recall: 0.7568
# Epoch 30: val_accuracy did not improve from 0.81579
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 568ms/step - accuracy: 0.7586 - loss: 16.3482 - precision: 0.7586 - recall: 0.7586 - val_accuracy: 0.7632 - val_loss: 16.1450 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.7040 - loss: 16.1780 - precision: 0.7040 - recall: 0.7040
# Epoch 31: val_accuracy did not improve from 0.81579
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 473ms/step - accuracy: 0.7052 - loss: 16.1713 - precision: 0.7052 - recall: 0.7052 - val_accuracy: 0.7632 - val_loss: 15.9019 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 548ms/step - accuracy: 0.7492 - loss: 15.9038 - precision: 0.7492 - recall: 0.7492
# Epoch 32: val_accuracy did not improve from 0.81579
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 590ms/step - accuracy: 0.7528 - loss: 15.9035 - precision: 0.7528 - recall: 0.7528 - val_accuracy: 0.7895 - val_loss: 15.6945 - val_precision: 0.7895 - val_recall: 0.7895
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.7388 - loss: 15.6822 - precision: 0.7388 - recall: 0.7388
# Epoch 33: val_accuracy did not improve from 0.81579
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 479ms/step - accuracy: 0.7398 - loss: 15.6800 - precision: 0.7398 - recall: 0.7398 - val_accuracy: 0.7895 - val_loss: 15.5180 - val_precision: 0.7895 - val_recall: 0.7895
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.8039 - loss: 15.4632 - precision: 0.8039 - recall: 0.8039
# Epoch 34: val_accuracy improved from 0.81579 to 0.84211, saving model to best_fall_detection_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 559ms/step - accuracy: 0.7978 - loss: 15.4674 - precision: 0.7978 - recall: 0.7978 - val_accuracy: 0.8421 - val_loss: 15.3368 - val_precision: 0.8421 - val_recall: 0.8421
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.7944 - loss: 15.2368 - precision: 0.7944 - recall: 0.7944
# Epoch 35: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 477ms/step - accuracy: 0.7903 - loss: 15.2394 - precision: 0.7903 - recall: 0.7903 - val_accuracy: 0.7368 - val_loss: 15.2982 - val_precision: 0.7368 - val_recall: 0.7368
# Epoch 36/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - accuracy: 0.8067 - loss: 14.9397 - precision: 0.8067 - recall: 0.8067
# Epoch 36: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 604ms/step - accuracy: 0.8057 - loss: 14.9394 - precision: 0.8057 - recall: 0.8057 - val_accuracy: 0.8158 - val_loss: 15.1275 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 37/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.8308 - loss: 14.7870 - precision: 0.8308 - recall: 0.8308
# Epoch 37: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 483ms/step - accuracy: 0.8300 - loss: 14.7859 - precision: 0.8300 - recall: 0.8300 - val_accuracy: 0.7632 - val_loss: 15.0447 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 38/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.7706 - loss: 14.6208 - precision: 0.7706 - recall: 0.7706
# Epoch 38: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 590ms/step - accuracy: 0.7699 - loss: 14.6231 - precision: 0.7699 - recall: 0.7699 - val_accuracy: 0.7105 - val_loss: 14.8370 - val_precision: 0.7105 - val_recall: 0.7105
# Epoch 39/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.8237 - loss: 14.2892 - precision: 0.8237 - recall: 0.8237
# Epoch 39: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 465ms/step - accuracy: 0.8194 - loss: 14.2929 - precision: 0.8194 - recall: 0.8194 - val_accuracy: 0.6842 - val_loss: 14.8706 - val_precision: 0.6842 - val_recall: 0.6842
# Epoch 40/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.7725 - loss: 14.0813 - precision: 0.7725 - recall: 0.7725
# Epoch 40: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 472ms/step - accuracy: 0.7752 - loss: 14.0729 - precision: 0.7752 - recall: 0.7752 - val_accuracy: 0.6842 - val_loss: 14.6173 - val_precision: 0.6842 - val_recall: 0.6842
# Epoch 41/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.8440 - loss: 13.7649 - precision: 0.8440 - recall: 0.8440
# Epoch 41: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 504ms/step - accuracy: 0.8432 - loss: 13.7610 - precision: 0.8432 - recall: 0.8432 - val_accuracy: 0.8421 - val_loss: 13.8234 - val_precision: 0.8421 - val_recall: 0.8421
# Epoch 42/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - accuracy: 0.8400 - loss: 13.4534 - precision: 0.8400 - recall: 0.8400
# Epoch 42: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 571ms/step - accuracy: 0.8408 - loss: 13.4466 - precision: 0.8408 - recall: 0.8408 - val_accuracy: 0.8158 - val_loss: 13.5512 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 43/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.8975 - loss: 13.0318 - precision: 0.8975 - recall: 0.8975
# Epoch 43: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 587ms/step - accuracy: 0.8937 - loss: 13.0318 - precision: 0.8937 - recall: 0.8937 - val_accuracy: 0.8158 - val_loss: 13.0817 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 44/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.9374 - loss: 12.6138 - precision: 0.9374 - recall: 0.9374
# Epoch 44: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 469ms/step - accuracy: 0.9359 - loss: 12.6106 - precision: 0.9359 - recall: 0.9359 - val_accuracy: 0.8158 - val_loss: 12.9159 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 45/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - accuracy: 0.8889 - loss: 12.3366 - precision: 0.8889 - recall: 0.8889
# Epoch 45: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 563ms/step - accuracy: 0.8876 - loss: 12.3318 - precision: 0.8876 - recall: 0.8876 - val_accuracy: 0.7895 - val_loss: 12.5814 - val_precision: 0.7895 - val_recall: 0.7895
# Epoch 46/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.8909 - loss: 11.8438 - precision: 0.8909 - recall: 0.8909
# Epoch 46: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 485ms/step - accuracy: 0.8894 - loss: 11.8414 - precision: 0.8894 - recall: 0.8894 - val_accuracy: 0.7632 - val_loss: 12.0299 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 47/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.8964 - loss: 11.5879 - precision: 0.8964 - recall: 0.8964
# Epoch 47: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 576ms/step - accuracy: 0.8974 - loss: 11.5764 - precision: 0.8974 - recall: 0.8974 - val_accuracy: 0.8158 - val_loss: 11.7895 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 48/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.8738 - loss: 11.1273 - precision: 0.8738 - recall: 0.8738
# Epoch 48: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 553ms/step - accuracy: 0.8739 - loss: 11.1216 - precision: 0.8739 - recall: 0.8739 - val_accuracy: 0.8158 - val_loss: 11.2791 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 49/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.9069 - loss: 10.7487 - precision: 0.9069 - recall: 0.9069
# Epoch 49: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 470ms/step - accuracy: 0.9082 - loss: 10.7395 - precision: 0.9082 - recall: 0.9082 - val_accuracy: 0.8421 - val_loss: 10.8128 - val_precision: 0.8421 - val_recall: 0.8421
# Epoch 50/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.9118 - loss: 10.3268 - precision: 0.9118 - recall: 0.9118
# Epoch 50: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 580ms/step - accuracy: 0.9126 - loss: 10.3167 - precision: 0.9126 - recall: 0.9126 - val_accuracy: 0.8421 - val_loss: 10.8060 - val_precision: 0.8421 - val_recall: 0.8421
# Epoch 51/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9232 - loss: 9.9313 - precision: 0.9232 - recall: 0.9232
# Epoch 51: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 585ms/step - accuracy: 0.9218 - loss: 9.9264 - precision: 0.9218 - recall: 0.9218 - val_accuracy: 0.7895 - val_loss: 10.6410 - val_precision: 0.7895 - val_recall: 0.7895
# Epoch 52/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.9568 - loss: 9.4507 - precision: 0.9568 - recall: 0.9568
# Epoch 52: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 475ms/step - accuracy: 0.9559 - loss: 9.4453 - precision: 0.9559 - recall: 0.9559 - val_accuracy: 0.7368 - val_loss: 10.2375 - val_precision: 0.7368 - val_recall: 0.7368
# Epoch 53/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.9584 - loss: 8.9414 - precision: 0.9584 - recall: 0.9584
# Epoch 53: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 501ms/step - accuracy: 0.9586 - loss: 8.9330 - precision: 0.9586 - recall: 0.9586 - val_accuracy: 0.7632 - val_loss: 9.6598 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 54/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.8977 - loss: 8.5527 - precision: 0.8977 - recall: 0.8977
# Epoch 54: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 514ms/step - accuracy: 0.8999 - loss: 8.5445 - precision: 0.8999 - recall: 0.8999 - val_accuracy: 0.7895 - val_loss: 8.8369 - val_precision: 0.7895 - val_recall: 0.7895
# Epoch 55/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - accuracy: 0.9652 - loss: 7.9426 - precision: 0.9652 - recall: 0.9652
# Epoch 55: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 586ms/step - accuracy: 0.9636 - loss: 7.9361 - precision: 0.9636 - recall: 0.9636 - val_accuracy: 0.6842 - val_loss: 8.6741 - val_precision: 0.6842 - val_recall: 0.6842
# Epoch 56/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.9750 - loss: 7.3830 - precision: 0.9750 - recall: 0.9750
# Epoch 56: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 480ms/step - accuracy: 0.9737 - loss: 7.3764 - precision: 0.9737 - recall: 0.9737 - val_accuracy: 0.8158 - val_loss: 7.7264 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 57/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 560ms/step - accuracy: 0.9359 - loss: 7.0118 - precision: 0.9359 - recall: 0.9359
# Epoch 57: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 602ms/step - accuracy: 0.9363 - loss: 7.0045 - precision: 0.9363 - recall: 0.9363 - val_accuracy: 0.7895 - val_loss: 7.3443 - val_precision: 0.7895 - val_recall: 0.7895
# Epoch 58/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.9840 - loss: 6.4546 - precision: 0.9840 - recall: 0.9840
# Epoch 58: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 478ms/step - accuracy: 0.9837 - loss: 6.4469 - precision: 0.9837 - recall: 0.9837 - val_accuracy: 0.8158 - val_loss: 6.8889 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 59/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - accuracy: 0.9490 - loss: 6.0796 - precision: 0.9490 - recall: 0.9490
# Epoch 59: val_accuracy did not improve from 0.84211
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 519ms/step - accuracy: 0.9501 - loss: 6.0686 - precision: 0.9501 - recall: 0.9501 - val_accuracy: 0.7368 - val_loss: 7.0765 - val_precision: 0.7368 - val_recall: 0.7368
# Epoch 60/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - accuracy: 0.9603 - loss: 5.5889 - precision: 0.9603 - recall: 0.9603
# Epoch 60: val_accuracy improved from 0.84211 to 0.89474, saving model to best_fall_detection_model.keras
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 590ms/step - accuracy: 0.9609 - loss: 5.5798 - precision: 0.9609 - recall: 0.9609 - val_accuracy: 0.8947 - val_loss: 6.0378 - val_precision: 0.8947 - val_recall: 0.8947
# Epoch 61/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.9947 - loss: 5.0726 - precision: 0.9947 - recall: 0.9947
# Epoch 61: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 571ms/step - accuracy: 0.9946 - loss: 5.0643 - precision: 0.9946 - recall: 0.9946 - val_accuracy: 0.8421 - val_loss: 5.7399 - val_precision: 0.8421 - val_recall: 0.8421
# Epoch 62/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.9947 - loss: 4.6051 - precision: 0.9947 - recall: 0.9947
# Epoch 62: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 476ms/step - accuracy: 0.9946 - loss: 4.5971 - precision: 0.9946 - recall: 0.9946 - val_accuracy: 0.7105 - val_loss: 5.5938 - val_precision: 0.7105 - val_recall: 0.7105
# Epoch 63/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.9829 - loss: 4.2064 - precision: 0.9829 - recall: 0.9829
# Epoch 63: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 574ms/step - accuracy: 0.9821 - loss: 4.2005 - precision: 0.9821 - recall: 0.9821 - val_accuracy: 0.7632 - val_loss: 5.3111 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 64/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - accuracy: 0.9627 - loss: 3.9593 - precision: 0.9627 - recall: 0.9627
# Epoch 64: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 582ms/step - accuracy: 0.9613 - loss: 3.9603 - precision: 0.9613 - recall: 0.9613 - val_accuracy: 0.8158 - val_loss: 4.8249 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 65/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.9695 - loss: 3.6833 - precision: 0.9695 - recall: 0.9695
# Epoch 65: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 510ms/step - accuracy: 0.9704 - loss: 3.6789 - precision: 0.9704 - recall: 0.9704 - val_accuracy: 0.8158 - val_loss: 4.5750 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 66/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.9626 - loss: 3.4773 - precision: 0.9626 - recall: 0.9626
# Epoch 66: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 506ms/step - accuracy: 0.9612 - loss: 3.4763 - precision: 0.9612 - recall: 0.9612 - val_accuracy: 0.7368 - val_loss: 4.5217 - val_precision: 0.7368 - val_recall: 0.7368
# Epoch 67/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.9925 - loss: 3.1904 - precision: 0.9925 - recall: 0.9925
# Epoch 67: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 471ms/step - accuracy: 0.9920 - loss: 3.1882 - precision: 0.9920 - recall: 0.9920 - val_accuracy: 0.7895 - val_loss: 3.9913 - val_precision: 0.7895 - val_recall: 0.7895
# Epoch 68/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - accuracy: 0.9750 - loss: 2.9925 - precision: 0.9750 - recall: 0.9750
# Epoch 68: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 570ms/step - accuracy: 0.9755 - loss: 2.9881 - precision: 0.9755 - recall: 0.9755 - val_accuracy: 0.7105 - val_loss: 4.3384 - val_precision: 0.7105 - val_recall: 0.7105
# Epoch 69/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - accuracy: 0.9947 - loss: 2.7672 - precision: 0.9947 - recall: 0.9947
# Epoch 69: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 580ms/step - accuracy: 0.9946 - loss: 2.7640 - precision: 0.9946 - recall: 0.9946 - val_accuracy: 0.8158 - val_loss: 3.8014 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 70/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.9701 - loss: 2.6111 - precision: 0.9701 - recall: 0.9701
# Epoch 70: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 469ms/step - accuracy: 0.9705 - loss: 2.6069 - precision: 0.9705 - recall: 0.9705 - val_accuracy: 0.7632 - val_loss: 3.3601 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 71/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.9817 - loss: 2.4353 - precision: 0.9817 - recall: 0.9817
# Epoch 71: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 578ms/step - accuracy: 0.9827 - loss: 2.4301 - precision: 0.9827 - recall: 0.9827 - val_accuracy: 0.8158 - val_loss: 3.4707 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 72/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - accuracy: 0.9845 - loss: 2.2790 - precision: 0.9845 - recall: 0.9845
# Epoch 72: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 578ms/step - accuracy: 0.9830 - loss: 2.2805 - precision: 0.9830 - recall: 0.9830 - val_accuracy: 0.7632 - val_loss: 3.0622 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 73/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.9788 - loss: 2.1451 - precision: 0.9788 - recall: 0.9788
# Epoch 73: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 476ms/step - accuracy: 0.9790 - loss: 2.1436 - precision: 0.9790 - recall: 0.9790 - val_accuracy: 0.8158 - val_loss: 3.2013 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 74/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.9675 - loss: 2.0397 - precision: 0.9675 - recall: 0.9675
# Epoch 74: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 556ms/step - accuracy: 0.9668 - loss: 2.0390 - precision: 0.9668 - recall: 0.9668 - val_accuracy: 0.6842 - val_loss: 3.6046 - val_precision: 0.6842 - val_recall: 0.6842
# Epoch 75/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.9582 - loss: 1.9994 - precision: 0.9582 - recall: 0.9582
# Epoch 75: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 469ms/step - accuracy: 0.9578 - loss: 1.9953 - precision: 0.9578 - recall: 0.9578 - val_accuracy: 0.8158 - val_loss: 2.7451 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 76/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.9511 - loss: 1.9994 - precision: 0.9511 - recall: 0.9511
# Epoch 76: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 581ms/step - accuracy: 0.9532 - loss: 1.9915 - precision: 0.9532 - recall: 0.9532 - val_accuracy: 0.6579 - val_loss: 3.4292 - val_precision: 0.6579 - val_recall: 0.6579
# Epoch 77/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.9885 - loss: 1.7521 - precision: 0.9885 - recall: 0.9885
# Epoch 77: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 583ms/step - accuracy: 0.9877 - loss: 1.7513 - precision: 0.9877 - recall: 0.9877 - val_accuracy: 0.8158 - val_loss: 2.6232 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 78/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.9833 - loss: 1.7201 - precision: 0.9833 - recall: 0.9833
# Epoch 78: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 473ms/step - accuracy: 0.9824 - loss: 1.7197 - precision: 0.9824 - recall: 0.9824 - val_accuracy: 0.7105 - val_loss: 3.8755 - val_precision: 0.7105 - val_recall: 0.7105
# Epoch 79/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 554ms/step - accuracy: 0.9700 - loss: 1.7505 - precision: 0.9700 - recall: 0.9700
# Epoch 79: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 587ms/step - accuracy: 0.9709 - loss: 1.7445 - precision: 0.9709 - recall: 0.9709 - val_accuracy: 0.7105 - val_loss: 2.9430 - val_precision: 0.7105 - val_recall: 0.7105
# Epoch 80/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.9635 - loss: 1.6701 - precision: 0.9635 - recall: 0.9635
# Epoch 80: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 470ms/step - accuracy: 0.9638 - loss: 1.6694 - precision: 0.9638 - recall: 0.9638 - val_accuracy: 0.7632 - val_loss: 2.6690 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 81/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9901 - loss: 1.4615 - precision: 0.9901 - recall: 0.9901
# Epoch 81: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 583ms/step - accuracy: 0.9898 - loss: 1.4618 - precision: 0.9898 - recall: 0.9898 - val_accuracy: 0.8158 - val_loss: 2.1487 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 82/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.9733 - loss: 1.4241 - precision: 0.9733 - recall: 0.9733
# Epoch 82: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 490ms/step - accuracy: 0.9739 - loss: 1.4234 - precision: 0.9739 - recall: 0.9739 - val_accuracy: 0.5789 - val_loss: 5.0590 - val_precision: 0.5789 - val_recall: 0.5789
# Epoch 83/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.9433 - loss: 1.4937 - precision: 0.9433 - recall: 0.9433
# Epoch 83: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 503ms/step - accuracy: 0.9437 - loss: 1.4915 - precision: 0.9437 - recall: 0.9437 - val_accuracy: 0.8158 - val_loss: 1.9494 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 84/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - accuracy: 0.9530 - loss: 1.4287 - precision: 0.9530 - recall: 0.9530
# Epoch 84: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 584ms/step - accuracy: 0.9537 - loss: 1.4243 - precision: 0.9537 - recall: 0.9537 - val_accuracy: 0.7632 - val_loss: 2.1858 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 85/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 0.9260 - loss: 1.3813 - precision: 0.9260 - recall: 0.9260
# Epoch 85: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 607ms/step - accuracy: 0.9297 - loss: 1.3736 - precision: 0.9297 - recall: 0.9297 - val_accuracy: 0.7632 - val_loss: 2.1322 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 86/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.9817 - loss: 1.2479 - precision: 0.9817 - recall: 0.9817
# Epoch 86: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 468ms/step - accuracy: 0.9827 - loss: 1.2437 - precision: 0.9827 - recall: 0.9827 - val_accuracy: 0.7368 - val_loss: 2.3554 - val_precision: 0.7368 - val_recall: 0.7368
# Epoch 87/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.9841 - loss: 1.1695 - precision: 0.9841 - recall: 0.9841
# Epoch 87: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 547ms/step - accuracy: 0.9838 - loss: 1.1688 - precision: 0.9838 - recall: 0.9838 - val_accuracy: 0.7632 - val_loss: 2.6004 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 88/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - accuracy: 0.9730 - loss: 1.2212 - precision: 0.9730 - recall: 0.9730
# Epoch 88: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 575ms/step - accuracy: 0.9719 - loss: 1.2256 - precision: 0.9719 - recall: 0.9719 - val_accuracy: 0.6579 - val_loss: 3.1017 - val_precision: 0.6579 - val_recall: 0.6579
# Epoch 89/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.9931 - loss: 1.0427 - precision: 0.9931 - recall: 0.9931
# Epoch 89: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 464ms/step - accuracy: 0.9931 - loss: 1.0416 - precision: 0.9931 - recall: 0.9931 - val_accuracy: 0.7368 - val_loss: 2.2809 - val_precision: 0.7368 - val_recall: 0.7368
# Epoch 90/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - accuracy: 0.9620 - loss: 1.0488 - precision: 0.9620 - recall: 0.9620
# Epoch 90: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 555ms/step - accuracy: 0.9631 - loss: 1.0459 - precision: 0.9631 - recall: 0.9631 - val_accuracy: 0.7632 - val_loss: 1.9527 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 91/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.9856 - loss: 0.9741 - precision: 0.9856 - recall: 0.9856
# Epoch 91: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 471ms/step - accuracy: 0.9851 - loss: 0.9744 - precision: 0.9851 - recall: 0.9851 - val_accuracy: 0.8158 - val_loss: 1.8905 - val_precision: 0.8158 - val_recall: 0.8158
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - accuracy: 0.9906 - loss: 0.9359 - precision: 0.9906 - recall: 0.9906
# Epoch 92: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 567ms/step - accuracy: 0.9903 - loss: 0.9358 - precision: 0.9903 - recall: 0.9903 - val_accuracy: 0.7895 - val_loss: 1.9174 - val_precision: 0.7895 - val_recall: 0.7895
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - accuracy: 0.9664 - loss: 0.9507 - precision: 0.9664 - recall: 0.9664
# Epoch 93: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 569ms/step - accuracy: 0.9671 - loss: 0.9484 - precision: 0.9671 - recall: 0.9671 - val_accuracy: 0.7368 - val_loss: 1.6346 - val_precision: 0.7368 - val_recall: 0.7368
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.9906 - loss: 0.8765 - precision: 0.9906 - recall: 0.9906
# Epoch 94: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 473ms/step - accuracy: 0.9903 - loss: 0.8767 - precision: 0.9903 - recall: 0.9903 - val_accuracy: 0.8421 - val_loss: 1.5823 - val_precision: 0.8421 - val_recall: 0.8421
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.9864 - loss: 0.8786 - precision: 0.9864 - recall: 0.9864
# Epoch 95: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 495ms/step - accuracy: 0.9859 - loss: 0.8809 - precision: 0.9859 - recall: 0.9859 - val_accuracy: 0.7632 - val_loss: 2.3126 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - accuracy: 0.9947 - loss: 0.7841 - precision: 0.9947 - recall: 0.9947
# Epoch 96: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 584ms/step - accuracy: 0.9946 - loss: 0.7839 - precision: 0.9946 - recall: 0.9946 - val_accuracy: 0.7632 - val_loss: 1.8259 - val_precision: 0.7632 - val_recall: 0.7632
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 1.0000 - loss: 0.7340 - precision: 1.0000 - recall: 1.0000
# Epoch 97: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 569ms/step - accuracy: 1.0000 - loss: 0.7335 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.7895 - val_loss: 2.2907 - val_precision: 0.7895 - val_recall: 0.7895
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.9701 - loss: 0.7658 - precision: 0.9701 - recall: 0.9701
# Epoch 98: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 470ms/step - accuracy: 0.9705 - loss: 0.7646 - precision: 0.9705 - recall: 0.9705 - val_accuracy: 0.7895 - val_loss: 1.3394 - val_precision: 0.7895 - val_recall: 0.7895
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.9878 - loss: 0.7194 - precision: 0.9878 - recall: 0.9878
# Epoch 99: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 573ms/step - accuracy: 0.9877 - loss: 0.7187 - precision: 0.9877 - recall: 0.9877 - val_accuracy: 0.7105 - val_loss: 2.1635 - val_precision: 0.7105 - val_recall: 0.7105
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.9947 - loss: 0.7092 - precision: 0.9947 - recall: 0.9947
# Epoch 100: val_accuracy did not improve from 0.89474
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 572ms/step - accuracy: 0.9946 - loss: 0.7100 - precision: 0.9946 - recall: 0.9946 - val_accuracy: 0.7632 - val_loss: 1.5863 - val_precision: 0.7632 - val_recall: 0.7632
#
# Training completed successfully!
# ============================================================
# MODEL EVALUATION
# ============================================================
#
# Validation Results:
# Validation Loss: 1.3394
# Validation Accuracy: 0.7895
# Validation Precision: 0.7895
# Validation Recall: 0.7895
# Validation F1-Score: 0.7895
# Model saved as 'enhanced_fall_detection_model.keras'
#
# Final Validation Accuracy: 0.7895
#
# Complete!

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model(model, X_test, y_test):
    """Simple confusion matrix evaluation - standard approach"""

    # Get predictions
    y_pred = model.predict(X_test, verbose=0)

    # Convert predicted probabilities to class labels
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_test, axis=1)

    # Generate confusion matrix
    conf_matrix = confusion_matrix(y_true_classes, y_pred_classes)

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Predicted No Fall', 'Predicted Fall'],
                yticklabels=['Actual No Fall', 'Actual Fall'])

    plt.title('Confusion Matrix - Fall Detection')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

    # Calculate and display metrics
    tn, fp, fn, tp = conf_matrix.ravel()
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0 # Calculate Specificity

    print("Classification Results:")
    print(f"Accuracy:  {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall:    {recall:.4f}")
    print(f"Specificity: {specificity:.4f}") # Print Specificity
    print(f"F1-Score:  {f1_score:.4f}")

    # Display classification report
    target_names = ["No Fall", "Fall"]
    print("\nDetailed Classification Report:")
    print(classification_report(y_true_classes, y_pred_classes, target_names=target_names))

    return conf_matrix, y_pred

# Usage with validation set:
conf_matrix, predictions = evaluate_model(model, X_val, y_val)
# Out:
# Classification Results:
# Accuracy:  0.7895
# Precision: 0.7500
# Recall:    0.9545
# Specificity: 0.5625
# F1-Score:  0.8400
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#      No Fall       0.90      0.56      0.69        16
#         Fall       0.75      0.95      0.84        22
#
#     accuracy                           0.79        38
#    macro avg       0.82      0.76      0.77        38
# weighted avg       0.81      0.79      0.78        38
